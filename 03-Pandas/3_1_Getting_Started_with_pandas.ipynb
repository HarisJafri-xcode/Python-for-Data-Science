# %% [markdown]
# <a href="https://colab.research.google.com/github/HarisJafri-xcode/Python-for-Data-Science/blob/main/03-Pandas/3_1_Getting_Started_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# Pandas stand for Panel Data. Pandas is designed for working with tabular or heterogeneous data.
#
# We can import this Library into the Code via following Code.

# %%
import pandas as pd
import numpy as np # Importing NumPy is not neccessary but we shall surely need it

# %%
pd.set_option("display.max_rows", 20)     # number of rows to show
pd.set_option("display.max_columns", 10)  # number of columns to show
pd.set_option("display.width", 0)         # auto-adjust width

# %% [markdown]
# # Origin of Pandas DataFrame

# %%
# Constructing a Dictionary
data = {
    "a": [1, 2, 3],
    "b": [4, 5, 6],
    "c": [7, 8, 9],
    "d": [10, 11, 12]
    }

# %%
# Passing dictionary into pd.DataFrame as argument
df = pd.DataFrame(data)
df
# Out:
#    a  b  c   d
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12

# %% [markdown]
# # Inspecting a DataFrame

# %% [markdown]
# We don't create Dictionaries and then pass them in pd.DataFrame Function. Most of the time, we would have to import the DataSet inside the Notebook and load it as DataFrame.

# %%
file_path_homeless_data_set = 'https://raw.githubusercontent.com/HarisJafri-xcode/Python-for-Data-Science/refs/heads/main/05-Datasets/homelessness.csv'

# %%
df_homeless = pd.read_csv(file_path_homeless_data_set)

# %%
df_homeless.head() # inspecting first 5 rows
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
df_homeless.tail() # inspecting bottom 5 rows
# Out:
#                 region          state  individuals  family_members  state_pop
# 46      South Atlantic       Virginia         3928            2047    8501286
# 47             Pacific     Washington        16424            5880    7523869
# 48      South Atlantic  West Virginia         1021             222    1804291
# 49  East North Central      Wisconsin         2740            2167    5807406
# 50            Mountain        Wyoming          434             205     577601

# %%
df_homeless.describe()
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
df_homeless.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     int64
#  3   family_members  51 non-null     int64
#  4   state_pop       51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_homeless.shape
# Out:
# (51, 5)

# %% [markdown]
# # Parts of DataFrame

# %% [markdown]
# To better understand DataFrame objects, it's useful to know that they consist of three components, stored as attributes.

# %%
# df_homeless.values

# %%
df_homeless.columns
# Out:
# Index(['region', 'state', 'individuals', 'family_members', 'state_pop'], dtype='object')

# %%
df_homeless.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %% [markdown]
# # Sorting Rows

# %% [markdown]
# Rows can be sorted in ascending or descending order by the use of .sort_values() method.

# %%
df_homeless.sort_values("individuals").head()
# Out:
#                 region         state  individuals  family_members  state_pop
# 50            Mountain       Wyoming          434             205     577601
# 34  West North Central  North Dakota          467              75     758080
# 7       South Atlantic      Delaware          708             374     965479
# 39         New England  Rhode Island          747             354    1058287
# 45         New England       Vermont          780             511     624358

# %%
df_homeless.sort_values("family_members", ascending=False).head()
# Out:
#                 region          state  individuals  family_members  state_pop
# 32        Mid-Atlantic       New York        39827           52070   19530351
# 4              Pacific     California       109008           20964   39461588
# 21         New England  Massachusetts         6811           13257    6882635
# 9       South Atlantic        Florida        21443            9587   21244317
# 43  West South Central          Texas        19199            6111   28628666

# %%
df_homeless.sort_values(['region','family_members'], ascending=[True,False]).head()
# Out:
#                 region      state  individuals  family_members  state_pop
# 13  East North Central   Illinois         6752            3891   12723071
# 35  East North Central       Ohio         6929            3320   11676341
# 22  East North Central   Michigan         5209            3142    9984072
# 49  East North Central  Wisconsin         2740            2167    5807406
# 14  East North Central    Indiana         3776            1482    6695497

# %%
df_homeless.sort_values(['region','family_members'], ascending=[False,True]).head()
# Out:
#                 region         state  individuals  family_members  state_pop
# 3   West South Central      Arkansas         2280             432    3009733
# 18  West South Central     Louisiana         2540             519    4659690
# 36  West South Central      Oklahoma         2823            1048    3940235
# 43  West South Central         Texas        19199            6111   28628666
# 34  West North Central  North Dakota          467              75     758080

# %% [markdown]
# # Subsetting Columns

# %%
df_homeless['individuals'].head()
# Out:
# 0      2570
# 1      1434
# 2      7259
# 3      2280
# 4    109008
# Name: individuals, dtype: int64

# %%
df_homeless[['family_members','individuals']].head()
# Out:
#    family_members  individuals
# 0             864         2570
# 1             582         1434
# 2            2606         7259
# 3             432         2280
# 4           20964       109008

# %% [markdown]
# # Subsetting Rows

# %%
mask = df_homeless['individuals'] > 10000
df_homeless[mask]
# Out:
#                 region       state  individuals  family_members  state_pop
# 4              Pacific  California       109008           20964   39461588
# 9       South Atlantic     Florida        21443            9587   21244317
# 32        Mid-Atlantic    New York        39827           52070   19530351
# 37             Pacific      Oregon        11139            3337    4181886
# 43  West South Central       Texas        19199            6111   28628666
# 47             Pacific  Washington        16424            5880    7523869

# %%
df_homeless[df_homeless['region'] == 'Mountain']
# Out:
#       region       state  individuals  family_members  state_pop
# 2   Mountain     Arizona         7259            2606    7158024
# 5   Mountain    Colorado         7607            3250    5691287
# 12  Mountain       Idaho         1297             715    1750536
# 26  Mountain     Montana          983             422    1060665
# 28  Mountain      Nevada         7058             486    3027341
# 31  Mountain  New Mexico         1949             602    2092741
# 44  Mountain        Utah         1904             972    3153550
# 50  Mountain     Wyoming          434             205     577601

# %%
mask1 = df_homeless['region'] == 'Pacific'
mask2 = df_homeless['family_members'] < 1000
df_homeless[mask1 & mask2]
# Out:
#     region   state  individuals  family_members  state_pop
# 1  Pacific  Alaska         1434             582     735139

# %% [markdown]
# # Subsetting Rows by Categorical Variables

# %%
mask1 = df_homeless['region'] == 'Pacific'
mask2 = df_homeless['region'] == 'Mountain'
df_homeless[mask1 | mask2]
# Out:
#       region       state  individuals  family_members  state_pop
# 1    Pacific      Alaska         1434             582     735139
# 2   Mountain     Arizona         7259            2606    7158024
# 4    Pacific  California       109008           20964   39461588
# 5   Mountain    Colorado         7607            3250    5691287
# 11   Pacific      Hawaii         4131            2399    1420593
# 12  Mountain       Idaho         1297             715    1750536
# 26  Mountain     Montana          983             422    1060665
# 28  Mountain      Nevada         7058             486    3027341
# 31  Mountain  New Mexico         1949             602    2092741
# 37   Pacific      Oregon        11139            3337    4181886
# 44  Mountain        Utah         1904             972    3153550
# 47   Pacific  Washington        16424            5880    7523869
# 50  Mountain     Wyoming          434             205     577601

# %%
chosen_states = ['Pacific', 'Mountain']
mask = df_homeless['region'].isin(chosen_states)
df_homeless[mask]
# Out:
#       region       state  individuals  family_members  state_pop
# 1    Pacific      Alaska         1434             582     735139
# 2   Mountain     Arizona         7259            2606    7158024
# 4    Pacific  California       109008           20964   39461588
# 5   Mountain    Colorado         7607            3250    5691287
# 11   Pacific      Hawaii         4131            2399    1420593
# 12  Mountain       Idaho         1297             715    1750536
# 26  Mountain     Montana          983             422    1060665
# 28  Mountain      Nevada         7058             486    3027341
# 31  Mountain  New Mexico         1949             602    2092741
# 37   Pacific      Oregon        11139            3337    4181886
# 44  Mountain        Utah         1904             972    3153550
# 47   Pacific  Washington        16424            5880    7523869
# 50  Mountain     Wyoming          434             205     577601

# %% [markdown]
# # Adding New Columns

# %%
df_homeless['total'] = df_homeless['individuals'] + df_homeless['family_members']
df_homeless.head()
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588
#
#     total
# 0    3434
# 1    2016
# 2    9865
# 3    2712
# 4  129972

# %% [markdown]
# # Mixing Up

# %% [markdown]
# A Simple Question "Which state has the highest number of homeless individuals per 10,000 people in the state?"

# %%
df_homeless.head()
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588
#
#     total
# 0    3434
# 1    2016
# 2    9865
# 3    2712
# 4  129972

# %%
df_homeless['inviduals_per_10k'] = (df_homeless['individuals'] / df_homeless['state_pop']) * 10000
df_homeless.head()
# Out:
#                region       state  individuals  family_members  state_pop  \
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588
#
#     total  inviduals_per_10k
# 0    3434           5.258117
# 1    2016          19.506515
# 2    9865          10.141067
# 3    2712           7.575423
# 4  129972          27.623825

# %%
df_homeless.sort_values('inviduals_per_10k', ascending=False).head()
# Out:
#             region                 state  individuals  family_members  \
# 8   South Atlantic  District of Columbia         3770            3134
# 11         Pacific                Hawaii         4131            2399
# 4          Pacific            California       109008           20964
# 37         Pacific                Oregon        11139            3337
# 28        Mountain                Nevada         7058             486
#
#     state_pop   total  inviduals_per_10k
# 8      701547    6904          53.738381
# 11    1420593    6530          29.079406
# 4    39461588  129972          27.623825
# 37    4181886   14476          26.636307
# 28    3027341    7544          23.314189
